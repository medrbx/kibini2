# %%
import pandas as pd

import requests
import json
from unidecode import unidecode

from kiblib.utils.db import DbConn

# %%
def mod_borrower(userid, data):
    api_url = "http://cataloguekoha.ntrbx.local/cgi-bin/koha/rest.pl/user"
    url = f"{api_url}/{userid}"
    data = json.dumps(data)
    data2mod = f"data={data}"
    #print(data2mod)
    response = requests.put(url, data=data2mod)
    #print(f"{userid} : {response.content}")

# %%
db_conn = DbConn().create_engine()

# %% [markdown]
# # Préparation des données

# %%
adherents = pd.read_json("http://cataloguekoha.ntrbx.local/cgi-bin/koha/rest.pl/user")
adherents = adherents[['borrowernumber', 'cardnumber', 'userid', 'address', 'address2',
                       'city', 'state', 'zipcode', 'altcontactcountry',
                       'categorycode', 'dateenrolled', 'dateexpiry']]
adherents['address_norm'] = adherents['address'].str.lower()
adherents['address_norm'] = adherents['address_norm'].apply(unidecode)
adherents['address_norm'] = adherents['address_norm'].str.replace( "'", " ", regex=False)
adherents['address_norm'] = adherents['address_norm'].str.replace( "\s+", " ", regex=True)
len(adherents)
# Out:
# 31064

# %%
query = "SELECT * FROM statdb.iris"
adresses = pd.read_sql(query, db_conn)
adresses = adresses[['adresse', 'id_cicn2', 'irisInsee']]
adresses['address_norm'] = adresses['adresse'].str.lower()
adresses['address_norm'] = adresses['address_norm'].apply(unidecode)
adresses['address_norm'] = adresses['address_norm'].str.replace( "'", " ", regex=False)
adresses['address_norm'] = adresses['address_norm'].str.replace( "\s+", " ", regex=True)
len(adresses)
# Out:
# 26297

# %% [markdown]
# # Préparation des corrections

# %%
# on limite aux adresses à Roubaix
rbx = adherents[adherents['zipcode'].isin(['59100'])]

# pour les personnes physiques
rbx = rbx[rbx['categorycode'].isin(['BIBL', 'CSLT', 'MEDC', 'MEDB', 'MEDA', 'CSVT'])]
len(rbx)
# Out:
# 21940

# %%
rbx2 = rbx.merge(adresses, on = 'address_norm', how='left')
rbx2corr = rbx2[~rbx2['id_cicn2'].isna()]
rbx2corr = rbx2corr[(rbx2corr['state'] != rbx2corr['id_cicn2']) | (rbx2corr['altcontactcountry'] != rbx2corr['irisInsee']) ]
rbx2corr
# Out:
#        borrowernumber   cardnumber       userid  \
# 1225            19351  X0002813615  X0002813615
# 5088            55140  X0002646206  X0002646206
# 9593            67786  X0002574448  X0002574448
# 15450           76024  X0002732954  X0002732954
# 17380           78596  X0002730639  X0002730639
# 17690           79051  X0002813417  X0002813417
# 20319           82937  X0002813400  X0002813400
# 21934           85285  X0002813561  X0002813561
# 21935           85288  X0002813387  X0002813387
# 21936           85289  X0002813554  X0002813554
# 21937           85290  X0002813547  X0002813547
# 21938           85291  X0002813578  X0002813578
# 21939           85294  X0002813127  X0002813127
#
#                              address  \
# 1225                    55 RUE D HEM
# 5088           67 RUE DES FABRICANTS
# 9593            25 RUE DE L ALOUETTE
# 15450                  16 RUE BAYARD
# 17380            42 RUE HENRI DUNANT
# 17690                 12 RUE FENELON
# 20319                  96 RUE DROUOT
# 21934           14 RUE DE SEBASTOPOL
# 21935                14 RUE MAZAGRAN
# 21936       90 BOULEVARD DE FOURMIES
# 21937              58 RUE DU TRICHON
# 21938           2 RUE LOUIS LOUCHEUR
# 21939  67 BOULEVARD DE LA REPUBLIQUE
#
#                                            address2     city  state zipcode  \
# 1225                                                 ROUBAIX          59100
# 5088                                            N°3  ROUBAIX          59100
# 9593                                                 ROUBAIX  FP016   59100
# 15450                                                ROUBAIX          59100
# 17380  7D1 RESIDENCE MERMOZ - chez BELOUADAH  Ridha  ROUBAIX          59100
# 17690                                                ROUBAIX          59100
# 20319                                                ROUBAIX          59100
# 21934                              chambre FLORENCE  ROUBAIX          59100
# 21935                                                ROUBAIX   3067   59100
# 21936                                                ROUBAIX          59100
# 21937                                     Chambre 3  ROUBAIX   8845   59100
# 21938                                                ROUBAIX  12523   59100
# 21939                                                ROUBAIX          59100
#
#       altcontactcountry categorycode dateenrolled  dateexpiry  \
# 1225          595120801         MEDC   2006-02-09  2026-04-17
# 5088          595120601         MEDB   2019-07-26  2024-03-09
# 9593          595120203         BIBL   2022-09-13  2023-09-13
# 15450         595120303         BIBL   2023-11-19  2024-11-19
# 17380         595120603         BIBL   2024-03-21  2026-04-18
# 17690         595121001         BIBL   2024-04-19  2026-04-18
# 20319         595120401         BIBL   2024-12-01  2025-12-01
# 21934                           CSLT   2025-04-18  2026-04-18
# 21935                           CSLT   2025-04-18  2026-04-18
# 21936                           CSLT   2025-04-18  2026-04-18
# 21937                           BIBL   2025-04-18  2026-04-18
# 21938                           BIBL   2025-04-18  2026-04-18
# 21939                           BIBL   2025-04-18  2026-04-18
#
#                         address_norm                        adresse  \
# 1225                    55 rue d hem                   55 RUE D HEM
# 5088           67 rue des fabricants          67 RUE DES FABRICANTS
# 9593            25 rue de l alouette           25 RUE DE L ALOUETTE
# 15450                  16 rue bayard                  16 RUE BAYARD
# 17380            42 rue henri dunant            42 RUE HENRI DUNANT
# 17690                 12 rue fenelon                 12 RUE FENELON
# 20319                  96 rue drouot                  96 RUE DROUOT
# 21934           14 rue de sebastopol           14 RUE DE SEBASTOPOL
# 21935                14 rue mazagran                14 RUE MAZAGRAN
# 21936       90 boulevard de fourmies       90 BOULEVARD DE FOURMIES
# 21937              58 rue du trichon              58 RUE DU TRICHON
# 21938           2 rue louis loucheur           2 RUE LOUIS LOUCHEUR
# 21939  67 boulevard de la republique  67 BOULEVARD DE LA REPUBLIQUE
#
#               id_cicn2  irisInsee
# 1225             24491  595120801
# 5088              8920  595120601
# 9593             FP016  595120601
# 15450            15474  595120303
# 17380              291  595120603
# 17690  595120000006250  595121001
# 20319            23099  595120401
# 21934             6590  595120601
# 21935             3067  595120302
# 21936            20498  595120703
# 21937             8845  595120504
# 21938            12523  595121202
# 21939             1364  595120102

# %%
for record in rbx2corr[['cardnumber', 'userid', 'adresse', 'id_cicn2', 'irisInsee']][0:1010].to_dict(orient='records'):
    data = {
        'address': record['adresse'],
        'state': record['id_cicn2'],
        'altcontactcountry': record['irisInsee']
    }
    mod_borrower(record['userid'], data)
    print(record['cardnumber'], data)
# Out:
# X0002813615 {'address': '55 RUE D HEM', 'state': '24491', 'altcontactcountry': '595120801'}
# X0002646206 {'address': '67 RUE DES FABRICANTS', 'state': '8920', 'altcontactcountry': '595120601'}
# X0002574448 {'address': '25 RUE DE L ALOUETTE', 'state': 'FP016', 'altcontactcountry': '595120601'}
# X0002732954 {'address': '16 RUE BAYARD', 'state': '15474', 'altcontactcountry': '595120303'}
# X0002730639 {'address': '42 RUE HENRI DUNANT', 'state': '291', 'altcontactcountry': '595120603'}
# X0002813417 {'address': '12 RUE FENELON', 'state': '595120000006250', 'altcontactcountry': '595121001'}
# X0002813400 {'address': '96 RUE DROUOT', 'state': '23099', 'altcontactcountry': '595120401'}
# X0002813561 {'address': '14 RUE DE SEBASTOPOL', 'state': '6590', 'altcontactcountry': '595120601'}
# X0002813387 {'address': '14 RUE MAZAGRAN', 'state': '3067', 'altcontactcountry': '595120302'}
# X0002813554 {'address': '90 BOULEVARD DE FOURMIES', 'state': '20498', 'altcontactcountry': '595120703'}
# X0002813547 {'address': '58 RUE DU TRICHON', 'state': '8845', 'altcontactcountry': '595120504'}
# X0002813578 {'address': '2 RUE LOUIS LOUCHEUR', 'state': '12523', 'altcontactcountry': '595121202'}
# X0002813127 {'address': '67 BOULEVARD DE LA REPUBLIQUE', 'state': '1364', 'altcontactcountry': '595120102'}

# %%
rbx_ko = rbx2[rbx2['id_cicn2'].isna()]
rbx_ko
# Out:
#        borrowernumber   cardnumber       userid  \
# 26                379  X0001626184  X0001626184
# 33                471  X0001300152  X0001300152
# 72               1092  X0002580029  X0002580029
# 225              3567  X0002699493  X0002699493
# 278              4178  X0002438245  X0002438245
# ...               ...          ...          ...
# 21838           85142  X0002815169  X0002815169
# 21843           85148  X0002815091  X0002815091
# 21848           85155  X0002815022  X0002815022
# 21856           85163  X0002814681  X0002814681
# 21918           85258  X0002792002  X0002792002
#
#                                     address  \
# 26                  4 A AVENUE DES COTTAGES
# 33     115 C BOULEVARD DU GENERAL DE GAULLE
# 72               A 5 Allée Maurice Maertens
# 225              127 Bld. du Gal. de Gaulle
# 278                   13/42 rue Edgar Degas
# ...                                     ...
# 21838               44 rue de la guinguette
# 21843                 86 RUE HENRI CARRETTE
# 21848                     5 rue J. B. Notte
# 21856                       118H BD DE LYON
# 21918                   25 RUE ERNEST RENAN
#
#                                    address2     city            state zipcode  \
# 26                           Bat A3 Appt C3  ROUBAIX  595120000031834   59100
# 33                appt 524 rés Armenonville  ROUBAIX            19877   59100
# 72                                           ROUBAIX             None   59100
# 225                                          ROUBAIX                    59100
# 278                                    None  ROUBAIX  595120000033066   59100
# ...                                     ...      ...              ...     ...
# 21838                                        ROUBAIX                    59100
# 21843                                        ROUBAIX            17793   59100
# 21848  Ent A Appt 42-chez  ZOUGHEBI Hassiba  ROUBAIX                    59100
# 21856                                        ROUBAIX                    59100
# 21918                                        ROUBAIX                    59100
#
#       altcontactcountry categorycode dateenrolled  dateexpiry  \
# 26            595120701         BIBL   2005-03-31  2025-05-07
# 33            595120701         BIBL   2005-03-31  2026-01-28
# 72            595120902         MEDC   2005-08-27  2025-10-08
# 225           595120803         BIBL   2024-02-27  2025-02-27
# 278           595121302         BIBL   2012-01-11  2025-04-11
# ...                 ...          ...          ...         ...
# 21838                           CSLT   2025-04-08  2026-04-08
# 21843         595120203         BIBL   2025-04-09  2026-04-09
# 21848                           BIBL   2025-04-09  2026-04-09
# 21856                           BIBL   2025-04-09  2026-04-09
# 21918                           BIBL   2025-04-17  2026-04-17
#
#                                address_norm adresse id_cicn2 irisInsee
# 26                  4 a avenue des cottages     NaN      NaN       NaN
# 33     115 c boulevard du general de gaulle     NaN      NaN       NaN
# 72               a 5 allee maurice maertens     NaN      NaN       NaN
# 225              127 bld. du gal. de gaulle     NaN      NaN       NaN
# 278                   13/42 rue edgar degas     NaN      NaN       NaN
# ...                                     ...     ...      ...       ...
# 21838               44 rue de la guinguette     NaN      NaN       NaN
# 21843                 86 rue henri carrette     NaN      NaN       NaN
# 21848                     5 rue j. b. notte     NaN      NaN       NaN
# 21856                       118h bd de lyon     NaN      NaN       NaN
# 21918                   25 rue ernest renan     NaN      NaN       NaN
#
# [616 rows x 16 columns]

# %%
rbx_ko.groupby('address_norm')['borrowernumber'].count().reset_index().sort_values(by='borrowernumber', ascending=False)
# Out:
#                            address_norm  borrowernumber
# 45             11 rue winston churchill              19
# 380          46 rue du capitaine aubert              18
# 310               35 rue henri carrette              11
# 97                    14 rue de l ouest               9
# 337                     4 rue de l alma               9
# ..                                  ...             ...
# 243                  26/28 rue de lille               1
# 245        26boulevard de la republique               1
# 246  27 avenue des nations unies appt 1               1
# 247        27 bis boulevard beaurepaire               1
# 646                 xxxxxxxxxxxxxxxxxxx               1
#
# [647 rows x 2 columns]

# %%
ad = pd.read_csv("/home/kibini/kibini2/data/koha_address_corr_ok.csv")
ad = ad.merge(adresses[['id_cicn2', 'irisInsee']], on='id_cicn2', how='left')
ad
# Out:
#                            address_norm               new_address_norm  \
# 0                 35 rue henri carrette          35 rue henri carrette
# 1               11 b rue henri carrette        11 b rue henri carrette
# 2                 86 rue henri carrette          86 rue henri carrette
# 3                 55 bis rue du fresnoy            55 b rue du fresnoy
# 4                 54 rue henri carrette          54 rue henri carrette
# ..                                  ...                            ...
# 282               27 d14 rue la bruyere            27 d rue la bruyere
# 283                  26/28 rue de lille                26 rue de lille
# 284        26boulevard de la republique  26 boulevard de la republique
# 285  27 avenue des nations unies appt 1    27 avenue des nations unies
# 286        27 bis boulevard beaurepaire     27 b boulevard beaurepaire
#
#     id_cicn2                    new_address  irisInsee
# 0      26224          35 RUE HENRI CARRETTE  595120201
# 1      19724        11 B RUE HENRI CARRETTE  595120201
# 2      17793          86 RUE HENRI CARRETTE  595120203
# 3      25825            55 B RUE DU FRESNOY  595120102
# 4       1476          54 RUE HENRI CARRETTE  595120201
# ..       ...                            ...        ...
# 282    24949            27 D RUE LA BRUYERE  595120303
# 283    21594                26 RUE DE LILLE  595120601
# 284    17833  26 BOULEVARD DE LA REPUBLIQUE  595120102
# 285      731    27 AVENUE DES NATIONS UNIES  595120601
# 286    22052     27 B BOULEVARD BEAUREPAIRE  595121003
#
# [287 rows x 5 columns]

# %%
rbx2corr = rbx[['borrowernumber', 'cardnumber', 'userid', 'address_norm']].merge(ad, on = 'address_norm', how='inner')
rbx2corr
# Out:
#      borrowernumber   cardnumber       userid                    address_norm  \
# 0              3152  X0001495559  X0001495559            50 rue edgard quinet
# 1              3764  X0002571829  X0002571829  50 boulevard du general chanzy
# 2              4108  X0001670905  X0001670905       65 bis rue de constantine
# 3              4917  X0002400655  X0002400655           92 rue henri carrette
# 4             22379  X0002715728  X0002715728           92 rue henri carrette
# ..              ...          ...          ...                             ...
# 358           84761  X0002820156  X0002820156            34 rue saint quentin
# 359           84946  X0002817286  X0002817286        189 rue du cocq francais
# 360           85070  X0002816388  X0002816388                    42 rue valon
# 361           85090  X0002815756  X0002815756              23 rue beaurewaert
# 362           85120  X0002815367  X0002815367                 15 rue favreuil
#
#              new_address_norm id_cicn2               new_address  irisInsee
# 0         50 rue edgar quinet    12733       50 RUE EDGAR QUINET  595121201
# 1    50 rue du general chanzy     2972  50 RUE DU GENERAL CHANZY  595120801
# 2     65 b rue de constantine    22690   65 B RUE DE CONSTANTINE  595120302
# 3       92 rue henri carrette    10867     92 RUE HENRI CARRETTE  595120203
# 4       92 rue henri carrette    10867     92 RUE HENRI CARRETTE  595120203
# ..                        ...      ...                       ...        ...
# 358   34 rue de saint quentin    11595   34 RUE DE SAINT QUENTIN  595120903
# 359   189 rue du coq francais     2035   189 RUE DU COQ FRANCAIS  595120901
# 360             42 rue vallon    10922             42 RUE VALLON  595120203
# 361     23 rue de beaurewaert      514     23 RUE DE BEAUREWAERT  595120903
# 362        15 rue de favreuil    11166        15 RUE DE FAVREUIL  595120101
#
# [363 rows x 8 columns]

# %%
for record in rbx2corr[['cardnumber', 'userid', 'new_address', 'id_cicn2', 'irisInsee']][0:1010].to_dict(orient='records'):
    data = {
        'address': record['new_address'],
        'state': record['id_cicn2'],
        'altcontactcountry': record['irisInsee']
    }
    mod_borrower(record['userid'], data)
    print(record['cardnumber'], data)
# Out:
# X0001495559 {'address': '50 RUE EDGAR QUINET', 'state': '12733', 'altcontactcountry': '595121201'}
# X0002571829 {'address': '50 RUE DU GENERAL CHANZY', 'state': '2972', 'altcontactcountry': '595120801'}
# X0001670905 {'address': '65 B RUE DE CONSTANTINE', 'state': '22690', 'altcontactcountry': '595120302'}
# X0002400655 {'address': '92 RUE HENRI CARRETTE', 'state': '10867', 'altcontactcountry': '595120203'}
# X0002715728 {'address': '92 RUE HENRI CARRETTE', 'state': '10867', 'altcontactcountry': '595120203'}
# x0002806334 {'address': '92 RUE HENRI CARRETTE', 'state': '10867', 'altcontactcountry': '595120203'}
# X0001802502 {'address': '5 E RUE DE CARIHEM', 'state': '22211', 'altcontactcountry': '595121103'}
# X0001844766 {'address': '4 COUR CAZIER, 68 RUE DE LA VIGNE', 'state': '31749', 'altcontactcountry': '595120402'}
# X0002572796 {'address': '160 AVENUE JULES BRAME', 'state': '21820', 'altcontactcountry': '595121101'}
# X0002572789 {'address': '160 AVENUE JULES BRAME', 'state': '21820', 'altcontactcountry': '595121101'}
# X0001924787 {'address': '80 SAINT JOSEPH', 'state': '24975', 'altcontactcountry': '595120303'}
# X0001664742 {'address': '2 ROND POINT DES TOURELLES', 'state': '20237', 'altcontactcountry': '595121302'}
# X0002687827 {'address': '255 RUE DE LANNOY', 'state': '1827', 'altcontactcountry': '595120902'}
# X0002837314 {'address': '18 RUE ROSA BONHEUR', 'state': '13984', 'altcontactcountry': '595120902'}
# X0001347667 {'address': '39 /4 RUE DE BLANCHEMAILLE', 'state': '9980', 'altcontactcountry': '595120602'}
# X0002288970 {'address': '56 B GRANDE RUE', 'state': '22095', 'altcontactcountry': '595120601'}
# X0002606439 {'address': '5 RUE DU BRONDELOIRE', 'state': '11226', 'altcontactcountry': '595120501'}
# X0002500195 {'address': '66 RUE JULES WATTEEUW', 'state': '22371', 'altcontactcountry': '595120603'}
# X0002541532 {'address': '61 RUE JEAN BAPTISTE NOTTE', 'state': '9893', 'altcontactcountry': '595120803'}
# X0002174334 {'address': '84 RUE DROUOT', 'state': '15355', 'altcontactcountry': '595120401'}
# X0002738925 {'address': '26 BOULEVARD DE LA REPUBLIQUE', 'state': '17833', 'altcontactcountry': '595120102'}
# X0002732527 {'address': '46 RUE DE L ESPERANCE', 'state': '6391', 'altcontactcountry': '595120601'}
# X0002099811 {'address': '8 RUE HENRI BOSSUT', 'state': '3007', 'altcontactcountry': '595120702'}
# X0002283746 {'address': '128 B GRANDE RUE', 'state': '13311', 'altcontactcountry': '595120601'}
# X0002528113 {'address': '45 RUE EDGAR QUINET', 'state': '5622', 'altcontactcountry': '595121201'}
# X0002473031 {'address': '301 GRANDE RUE', 'state': '22601', 'altcontactcountry': '595120301'}
# X0002765600 {'address': '19 B RUE DE L INDUSTRIE', 'state': '24656', 'altcontactcountry': '595120503'}
# X0002765594 {'address': '19 B RUE DE L INDUSTRIE', 'state': '24656', 'altcontactcountry': '595120503'}
# X0002765587 {'address': '19 B RUE DE L INDUSTRIE', 'state': '24656', 'altcontactcountry': '595120503'}
# X0002352091 {'address': '65 RUE DUPUY DE LOME', 'state': '519', 'altcontactcountry': '595120802'}
# X0002352060 {'address': '65 RUE DUPUY DE LOME', 'state': '519', 'altcontactcountry': '595120802'}
# X0002311395 {'address': '31 RUE JEAN MONNET', 'state': '17917', 'altcontactcountry': '595120602'}
# X0002795768 {'address': '27 RUE VALLON', 'state': '6144', 'altcontactcountry': '595120203'}
# X0002695334 {'address': '9 RUE HENRI CARRETTE', 'state': '19727', 'altcontactcountry': '595120201'}
# X0002771533 {'address': '11 B RUE HENRI CARRETTE', 'state': '19724', 'altcontactcountry': '595120201'}
# X0002771557 {'address': '11 B RUE HENRI CARRETTE', 'state': '19724', 'altcontactcountry': '595120201'}
# X0002771540 {'address': '11 B RUE HENRI CARRETTE', 'state': '19724', 'altcontactcountry': '595120201'}
# X0002305981 {'address': '11 B RUE HENRI CARRETTE', 'state': '19724', 'altcontactcountry': '595120201'}
# X0002771564 {'address': '11 B RUE HENRI CARRETTE', 'state': '19724', 'altcontactcountry': '595120201'}
# X0002151441 {'address': '29 B RUE DE SEBASTOPOL', 'state': '21603', 'altcontactcountry': '595120601'}
# X0002059532 {'address': '72 RUE HENRI CARRETTE', 'state': '6109', 'altcontactcountry': '595120203'}
# X0002787817 {'address': '72 RUE HENRI CARRETTE', 'state': '6109', 'altcontactcountry': '595120203'}
# X0002586076 {'address': '5 RUE DE LA POTENNERIE', 'state': '5168', 'altcontactcountry': '595120802'}
# X0002586083 {'address': '5 RUE DE LA POTENNERIE', 'state': '5168', 'altcontactcountry': '595120802'}
# X0002748269 {'address': '5 RUE DE LA POTENNERIE', 'state': '5168', 'altcontactcountry': '595120802'}
# X0002248806 {'address': '99 RUE DE BEAUREWAERT', 'state': '20738', 'altcontactcountry': '595120903'}
# X0002250199 {'address': '42 RUE HENRI DUNANT', 'state': '291', 'altcontactcountry': '595120603'}
# X0002250168 {'address': '42 RUE HENRI DUNANT', 'state': '291', 'altcontactcountry': '595120603'}
# X0002330556 {'address': '42 RUE HENRI DUNANT', 'state': '291', 'altcontactcountry': '595120603'}
# X0002337722 {'address': '255 RUE DE LANNOY', 'state': '1827', 'altcontactcountry': '595120902'}
# X0002276755 {'address': '11 RUE GALVANI', 'state': '12948', 'altcontactcountry': '595120403'}
# X0002225449 {'address': '5 RUE SAINT ROCH', 'state': '13668', 'altcontactcountry': '595120503'}
# X0002225470 {'address': '5 RUE SAINT ROCH', 'state': '13668', 'altcontactcountry': '595120503'}
# X0002287676 {'address': '62 RUE SAINT JOSEPH', 'state': '8287', 'altcontactcountry': '595120303'}
# X0002756691 {'address': '62 RUE SAINT JOSEPH', 'state': '8287', 'altcontactcountry': '595120303'}
# X0002727653 {'address': '62 RUE SAINT JOSEPH', 'state': '8287', 'altcontactcountry': '595120303'}
# X0002686813 {'address': '55 B RUE DU FRESNOY', 'state': '25825', 'altcontactcountry': '595120102'}
# X0002545400 {'address': '55 B RUE DU FRESNOY', 'state': '25825', 'altcontactcountry': '595120102'}
# X0002282244 {'address': '55 B RUE DU FRESNOY', 'state': '25825', 'altcontactcountry': '595120102'}
# X0002545394 {'address': '55 B RUE DU FRESNOY', 'state': '25825', 'altcontactcountry': '595120102'}
# X0002539782 {'address': '47 B RUE DE MOUVAUX', 'state': '21538', 'altcontactcountry': '595120101'}
# X0002204819 {'address': '68 B RUE DE CARIHEM', 'state': '22210', 'altcontactcountry': '595121103'}
# X0002377582 {'address': '31 AVENUE ANATOLE FRANCE', 'state': '7628', 'altcontactcountry': '595120702'}
# X0002380698 {'address': '0 SQUARE PIERRE DESTOMBES', 'state': '641', 'altcontactcountry': '595121001'}
# X0002380681 {'address': '0 SQUARE PIERRE DESTOMBES', 'state': '641', 'altcontactcountry': '595121001'}
# X0002213651 {'address': '10 RANGEE FARVACQUE, 11B RUE BOUCICAUT', 'state': '9425', 'altcontactcountry': '595121103'}
# X0002373058 {'address': '187 RUE DUPUY DE LOME', 'state': '7568', 'altcontactcountry': '595120802'}
# X0002411408 {'address': '26 BOULEVARD DE CAMBRAI', 'state': '11367', 'altcontactcountry': '595120701'}
# X0002477794 {'address': '26 BOULEVARD DE CAMBRAI', 'state': '11367', 'altcontactcountry': '595120701'}
# X0002414799 {'address': '67 RUE JULES WATTEEUW', 'state': '595120000004040', 'altcontactcountry': '595120603'}
# X0002274799 {'address': '0 A SQUARE DES MULLIERS', 'state': '22429', 'altcontactcountry': '595120602'}
# X0002600314 {'address': '13 RUE DE BARBIEUX', 'state': '7603', 'altcontactcountry': '595120702'}
# X0002278711 {'address': '41 RUE HENRI CARRETTE', 'state': '10845', 'altcontactcountry': '595120201'}
# X0002324494 {'address': '41 RUE HENRI CARRETTE', 'state': '10845', 'altcontactcountry': '595120201'}
# X0002448978 {'address': '2 B RUE DE LA CONFERENCE', 'state': '595120000029243', 'altcontactcountry': '595120301'}
# X0002449685 {'address': '13 RUE HENRI CARRETTE', 'state': '19723', 'altcontactcountry': '595120201'}
# X0002310381 {'address': '3 CLOS GUSTAVE EIFFEL', 'state': '20433', 'altcontactcountry': '595120803'}
# X0002310398 {'address': '3 CLOS GUSTAVE EIFFEL', 'state': '20433', 'altcontactcountry': '595120803'}
# X0002707808 {'address': '9 RUE DES TISSERANDS', 'state': '22399', 'altcontactcountry': '595120201'}
# X0002314433 {'address': '18 B RUE BEAUMARCHAIS', 'state': '21086', 'altcontactcountry': '595121203'}
# X0002359663 {'address': '4 RUE DE MAUBEUGE', 'state': '12310', 'altcontactcountry': '595120802'}
# X0002359687 {'address': '4 RUE DE MAUBEUGE', 'state': '12310', 'altcontactcountry': '595120802'}
# X0002359700 {'address': '4 RUE DE MAUBEUGE', 'state': '12310', 'altcontactcountry': '595120802'}
# X0002359816 {'address': '63 RUE JEAN BAPTISTE COROT', 'state': '20461', 'altcontactcountry': '595121201'}
# X0002457130 {'address': '63 RUE JEAN BAPTISTE COROT', 'state': '20461', 'altcontactcountry': '595121201'}
# X0002360959 {'address': '56 RUE PIGOUCHE', 'state': '595120000032987', 'altcontactcountry': '595120703'}
# X0002427355 {'address': '0 A GALON D EAU', 'state': '20752', 'altcontactcountry': '595120403'}
# X0002427706 {'address': '0 BAT A RUE DU DOCTEUR ALBERT SCHWEITZER', 'state': '311', 'altcontactcountry': '595120603'}
# X0002430287 {'address': '13 RUE DU SAINT REDEMPTEUR', 'state': '9355', 'altcontactcountry': '595121001'}
# X0002610108 {'address': '5 PLACEBODART TIMAL', 'state': '15886', 'altcontactcountry': '595120601'}
# X0002477220 {'address': '9 RUE CHARLES PRANARD', 'state': '10918', 'altcontactcountry': '595121302'}
# X0002457826 {'address': '215 QUAI DE BORDEAUX', 'state': '8263', 'altcontactcountry': '595120303'}
# X0002459684 {'address': '352 GRANDE RUE', 'state': '10332', 'altcontactcountry': '595120301'}
# X0002460185 {'address': '14 RUE DU GENERAL SARRAIL', 'state': '18084', 'altcontactcountry': '595120601'}
# X0002461397 {'address': '11 RUE HENRI CARRETTE', 'state': '19725', 'altcontactcountry': '595120201'}
# X0002462431 {'address': '398 AVENUE DES NATIONS UNIES', 'state': '8362', 'altcontactcountry': '595120201'}
# X0002468594 {'address': '18 PLACE DE LA FOSSE AUX CHENES', 'state': '17926', 'altcontactcountry': '595120303'}
# X0002603148 {'address': '11 RUE DE LA HALLE', 'state': '20817', 'altcontactcountry': '595120601'}
# X0002469430 {'address': '65 B RUE DU TRICHON', 'state': '3411', 'altcontactcountry': '595120504'}
# X0002469447 {'address': '65 B RUE DU TRICHON', 'state': '3411', 'altcontactcountry': '595120504'}
# X0002296371 {'address': '7 RUE DU DOCTEUR ALBERT SCHWEITZER', 'state': '23131', 'altcontactcountry': '595120603'}
# X0002542485 {'address': '7 RUE DU DOCTEUR ALBERT SCHWEITZER', 'state': '23131', 'altcontactcountry': '595120603'}
# X0002747521 {'address': '158 RUE DE LA POTENNERIE', 'state': '19363', 'altcontactcountry': '595120802'}
# X0002470443 {'address': '31 B RUE DU BOIS', 'state': '30462', 'altcontactcountry': '595120601'}
# X0002473314 {'address': '150 T GRANDE RUE', 'state': '19822', 'altcontactcountry': '595120403'}
# X0002486062 {'address': '82 RUE DUPUY DE LOME', 'state': '2834', 'altcontactcountry': '595120803'}
# X0002792170 {'address': '46 RUE DES TISSERANDS', 'state': '22416', 'altcontactcountry': '595120201'}
# X0002487342 {'address': '1 A RUE STEPHENSON', 'state': '20602', 'altcontactcountry': '595120202'}
# X0002492810 {'address': '30 AVENUE JEAN JAURES', 'state': '21795', 'altcontactcountry': '595120701'}
# X0002497075 {'address': '30 RUE HENRI CARRETTE', 'state': '21015', 'altcontactcountry': '595120201'}
# X0002577555 {'address': '30 RUE HENRI CARRETTE', 'state': '21015', 'altcontactcountry': '595120201'}
# X0002497952 {'address': '9 RUE DROUOT', 'state': '8301', 'altcontactcountry': '595120401'}
# X0002499666 {'address': '40 BOULEVARD DU GENERAL LECLERC', 'state': '6606', 'altcontactcountry': '595120603'}
# X0002502939 {'address': '115 BOULEVARD DU GENERAL DE GAULLE', 'state': '19877', 'altcontactcountry': '595120701'}
# X0002504766 {'address': '39 /4 RUE DE BLANCHEMAILLE', 'state': '9980', 'altcontactcountry': '595120602'}
# X0082533483 {'address': '4 RUE LA ROCHEFOUCAULD', 'state': '14713', 'altcontactcountry': '595120803'}
# X0002733036 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002575025 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002367088 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002641584 {'address': '6 RUE BOURGELAT', 'state': '11114', 'altcontactcountry': '595120101'}
# X0002552521 {'address': '1 RUE WINSTON CHURCHILL', 'state': 'FP010', 'altcontactcountry': '595120603'}
# X0002553696 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002508665 {'address': '168 AVENUE LINNE', 'state': '20412', 'altcontactcountry': '595121201'}
# X0002645759 {'address': '168 AVENUE LINNE', 'state': '20412', 'altcontactcountry': '595121201'}
# X0002516578 {'address': '296 AVENUE GUSTAVE DELORY', 'state': '20118', 'altcontactcountry': '595120703'}
# X0002794709 {'address': '10 RUE DAGUESSEAU', 'state': '9995', 'altcontactcountry': '595120801'}
# X0002517742 {'address': '72 BOULEVARD MONTESQUIEU', 'state': '8796', 'altcontactcountry': '595120502'}
# X0002518954 {'address': '10 B RUE HENRI DELVARRE', 'state': '21558', 'altcontactcountry': '595121202'}
# X0002841144 {'address': '10 B RUE HENRI DELVARRE', 'state': '21558', 'altcontactcountry': '595121202'}
# X0002524689 {'address': '11 RUE DU DOCTEUR ALBERT SCHWEITZER', 'state': '18767', 'altcontactcountry': '595120603'}
# X0002578958 {'address': '187 RUE DE L EPEULE', 'state': '23460', 'altcontactcountry': '595120502'}
# X0002564197 {'address': '178 RUE D INKERMANN', 'state': '24556', 'altcontactcountry': '595120503'}
# X0002565149 {'address': '58 RUE DU MARECHAL FOCH', 'state': '8926', 'altcontactcountry': '595120601'}
# X0002567372 {'address': '7 SQUARE FRANCIS BOUSQUET', 'state': '20190', 'altcontactcountry': '595120803'}
# X0002584768 {'address': '7 SQUARE FRANCIS BOUSQUET', 'state': '20190', 'altcontactcountry': '595120803'}
# X0002567693 {'address': '24 RUE HENRI CARRETTE', 'state': '13213', 'altcontactcountry': '595120201'}
# X0002567709 {'address': '24 RUE HENRI CARRETTE', 'state': '13213', 'altcontactcountry': '595120201'}
# X0002568058 {'address': '154 AVENUE JULES BRAME', 'state': '21861', 'altcontactcountry': '595121101'}
# X0002568454 {'address': '2 RUE DE LA TORTUE', 'state': '9406', 'altcontactcountry': '595121001'}
# X0002586229 {'address': '7 CHEMIN LEON ALLART', 'state': '595120000003742', 'altcontactcountry': '595120403'}
# X0002569291 {'address': '52 RUE HENRI CARRETTE', 'state': '26222', 'altcontactcountry': '595120201'}
# X0002758879 {'address': '49 RUE DE MAUBEUGE', 'state': '9942', 'altcontactcountry': '595120802'}
# X0002758855 {'address': '49 RUE DE MAUBEUGE', 'state': '9942', 'altcontactcountry': '595120802'}
# X0002569666 {'address': '54 AVENUE GUSTAVE DELORY', 'state': '38318', 'altcontactcountry': '595120703'}
# X0002570273 {'address': '34 RUE AUGUSTEBLANQUI', 'state': '19395', 'altcontactcountry': '595120801'}
# X0002573083 {'address': '26 RUE DE LILLE', 'state': '21594', 'altcontactcountry': '595120601'}
# X0002574448 {'address': '25 RUE DE L ALOUETTE', 'state': 'FP016', 'altcontactcountry': '595121001'}
# X0002574448 {'address': '25 RUE DE L ALOUETTE', 'state': 'FP016', 'altcontactcountry': '595120502'}
# X0002574448 {'address': '25 RUE DE L ALOUETTE', 'state': 'FP016', 'altcontactcountry': '595120601'}
# X0002574448 {'address': '25 RUE DE L ALOUETTE', 'state': 'FP016', 'altcontactcountry': '595120203'}
# X0002574493 {'address': '16 RUE DE FAVREUIL', 'state': '1659', 'altcontactcountry': '595120101'}
# X0002576039 {'address': '150 T GRANDE RUE', 'state': '19822', 'altcontactcountry': '595120403'}
# X0002742083 {'address': '24 RUE MASSENA', 'state': '1792', 'altcontactcountry': '595120902'}
# X0002578712 {'address': '107 RUE DE BEAUREWAERT', 'state': '20810', 'altcontactcountry': '595120903'}
# X0002786445 {'address': '107 RUE DE BEAUREWAERT', 'state': '20810', 'altcontactcountry': '595120903'}
# X0002582245 {'address': '67 RUE D INKERMANN', 'state': '24002', 'altcontactcountry': '595120504'}
# X0002582498 {'address': '20 RUE HENRI CARRETTE', 'state': '3985', 'altcontactcountry': '595120201'}
# X0002582511 {'address': '20 RUE HENRI CARRETTE', 'state': '3985', 'altcontactcountry': '595120201'}
# X0002760421 {'address': '20 RUE HENRI CARRETTE', 'state': '3985', 'altcontactcountry': '595120201'}
# X0002585574 {'address': '62 RUE DE L ALOUETTE', 'state': '23449', 'altcontactcountry': '595120601'}
# X0002590912 {'address': '86 RUE HENRI CARRETTE', 'state': '17793', 'altcontactcountry': '595120203'}
# X0002555355 {'address': '86 RUE HENRI CARRETTE', 'state': '17793', 'altcontactcountry': '595120203'}
# x0002707082 {'address': '86 RUE HENRI CARRETTE', 'state': '17793', 'altcontactcountry': '595120203'}
# X0002815091 {'address': '86 RUE HENRI CARRETTE', 'state': '17793', 'altcontactcountry': '595120203'}
# X0002586892 {'address': '11 RUE DE LA POTENNERIE', 'state': '21427', 'altcontactcountry': '595120802'}
# X0002736556 {'address': '28 B RUE DU VIEIL ABREUVOIR', 'state': '8511', 'altcontactcountry': '595120602'}
# X0002598475 {'address': '141 AVENUE DE VERDUN', 'state': '19785', 'altcontactcountry': '595121102'}
# X0002718316 {'address': '273 RUE DE LANNOY', 'state': '9033', 'altcontactcountry': '595120902'}
# X0002601496 {'address': '5 RUE WINSTON CHURCHILL', 'state': '138', 'altcontactcountry': '595120603'}
# X0002602493 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002602509 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002602516 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002304830 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002643892 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002743394 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002774336 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002735740 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002709741 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002684949 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002787190 {'address': '35 RUE HENRI CARRETTE', 'state': '26224', 'altcontactcountry': '595120201'}
# X0002603025 {'address': '28 RUE DE MOUVAUX', 'state': '11097', 'altcontactcountry': '595120101'}
# X0002604084 {'address': '27 D RUE LA BRUYERE', 'state': '24949', 'altcontactcountry': '595120303'}
# X0002604381 {'address': '42 RUE HENRI CARRETTE', 'state': '13220', 'altcontactcountry': '595120201'}
# X0002728483 {'address': '42 RUE HENRI CARRETTE', 'state': '13220', 'altcontactcountry': '595120201'}
# X0002521107 {'address': '44 RUE LA FONTAINE', 'state': '14031', 'altcontactcountry': '595120901'}
# X0002521039 {'address': '39 RUE MARCELIN BERTHELOT', 'state': '20107', 'altcontactcountry': '595121202'}
# X0002639239 {'address': nan, 'state': nan, 'altcontactcountry': nan}
# X0002643038 {'address': '20 RUE DE LA POSTE', 'state': '20822', 'altcontactcountry': '595120601'}
# x0002637235 {'address': '68 RUE HENRI CARRETTE', 'state': '6108', 'altcontactcountry': '595120203'}
# X0002640235 {'address': '176 RUE DE L ALMA', 'state': '23933', 'altcontactcountry': '595120202'}
# X0002717418 {'address': '33 RUE DU VIEIL ABREUVOIR', 'state': '1537', 'altcontactcountry': '595120602'}
# X0002649108 {'address': '39 /4 RUE DE BLANCHEMAILLE', 'state': '9980', 'altcontactcountry': '595120602'}
# X0002650210 {'address': '206 /1 AVENUE DU PARC DES SPORTS, LOTISSEMENT MARECHAL JOFFRE', 'state': '9529', 'altcontactcountry': '595121103'}
# X0002651767 {'address': '27 AVENUE DES NATIONS UNIES', 'state': '731', 'altcontactcountry': '595120601'}
# X0002607344 {'address': '9 RUE DAMMARTIN', 'state': '4321', 'altcontactcountry': '595120701'}
# X0002653495 {'address': '66 RUE HENRI CARRETTE', 'state': '1497', 'altcontactcountry': '595120203'}
# X0002653488 {'address': '66 RUE HENRI CARRETTE', 'state': '1497', 'altcontactcountry': '595120203'}
# X0002609775 {'address': '95 RUE DE SEBASTOPOL', 'state': '13755', 'altcontactcountry': '595120504'}
# X0002754727 {'address': '4 RUE EDGAR DEGAS', 'state': '20241', 'altcontactcountry': '595121302'}
# X0002755052 {'address': '20 RUE DES TISSERANDS', 'state': '22415', 'altcontactcountry': '595120201'}
# X0002752129 {'address': '87 RUE MA CAMPAGNE', 'state': '5173', 'altcontactcountry': '595120802'}
# X0002750545 {'address': '118 RUE DECREME', 'state': '579', 'altcontactcountry': '595120901'}
# X0002771106 {'address': '16 RUE DE LA POTENNERIE', 'state': '14740', 'altcontactcountry': '595120802'}
# X0002743646 {'address': '16 RUE DE LA POTENNERIE', 'state': '14740', 'altcontactcountry': '595120802'}
# X0002771502 {'address': '22 B RUE VILLARS', 'state': '12843', 'altcontactcountry': '595120402'}
# X0002773032 {'address': '54 RUE HENRI CARRETTE', 'state': '1476', 'altcontactcountry': '595120201'}
# X0002773056 {'address': '54 RUE HENRI CARRETTE', 'state': '1476', 'altcontactcountry': '595120201'}
# X0002773070 {'address': '54 RUE HENRI CARRETTE', 'state': '1476', 'altcontactcountry': '595120201'}
# X0002773063 {'address': '54 RUE HENRI CARRETTE', 'state': '1476', 'altcontactcountry': '595120201'}
# X0002768212 {'address': '9 RUE D YPRES', 'state': '391', 'altcontactcountry': '595121102'}
# X0002773476 {'address': '57 RUE DE ROCROI', 'state': '522', 'altcontactcountry': '595120901'}
# X0002633282 {'address': '1 RUE LEO LAGRANGE', 'state': '436', 'altcontactcountry': '595121102'}
# X0002765495 {'address': '3 RUE DE ROHAN', 'state': '8917', 'altcontactcountry': '595120504'}
# X0002765044 {'address': '9 RUE LA FONTAINE', 'state': '16243', 'altcontactcountry': '595120901'}
# X0002737140 {'address': '36 RUE HENRI CARRETTE', 'state': '8373', 'altcontactcountry': '595120201'}
# X0002736402 {'address': '16 RUE HENRI CARRETTE', 'state': '15527', 'altcontactcountry': '595120201'}
# X0002733920 {'address': '10 RUE DE LA POTENNERIE', 'state': '7548', 'altcontactcountry': '595120802'}
# X0002732480 {'address': '32 RUE TURGOT', 'state': '1445', 'altcontactcountry': '595120303'}
# X0002730226 {'address': '41 RUE DE SOLFERINO', 'state': '11070', 'altcontactcountry': '595120101'}
# X0002729961 {'address': '4 B RUE DE L ESPERANCE', 'state': '595120000015463', 'altcontactcountry': '595120601'}
# X0002729305 {'address': '5 AVENUE DES COTTAGES', 'state': '16038', 'altcontactcountry': '595120701'}
# X0002729114 {'address': '113 AVENUE DU PRESIDENT KENNEDY', 'state': '405', 'altcontactcountry': '595121101'}
# X0002729077 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002715698 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002728575 {'address': '5 PLACE DE L ABREUVOIR', 'state': '6294', 'altcontactcountry': '595120504'}
# X0002726823 {'address': '48 GRANDE RUE', 'state': '22103', 'altcontactcountry': '595120601'}
# X0002709727 {'address': '18 RUE DE BEAUMONT', 'state': '14546', 'altcontactcountry': '595120702'}
# X0002708331 {'address': '552 RUE DE LANNOY', 'state': '14514', 'altcontactcountry': '595121202'}
# X0002306537 {'address': '79 RUE DE L EPEULE', 'state': '24559', 'altcontactcountry': '595120502'}
# X0002775005 {'address': '74 A ALLEE DES SAULES', 'state': '21637', 'altcontactcountry': '595120502'}
# X0002708638 {'address': '9 RUE SAINT JEAN', 'state': '19173', 'altcontactcountry': '595120603'}
# X0002703084 {'address': '108 RUE LA FONTAINE', 'state': '4562', 'altcontactcountry': '595120901'}
# X0002708515 {'address': '110 AVENUE JULES BRAME', 'state': '21846', 'altcontactcountry': '595121101'}
# X0002710334 {'address': '12 RUE DE LA BASSE MASURE', 'state': '17678', 'altcontactcountry': '595120303'}
# X0002704203 {'address': '98 AVENUE DE LA FOSSE AUX CHENES', 'state': '21710', 'altcontactcountry': '595120201'}
# X0002704197 {'address': '36 RUE TURGOT', 'state': '20643', 'altcontactcountry': '595120303'}
# X0002767505 {'address': '41 RUE LEO LAGRANGE', 'state': '440', 'altcontactcountry': '595121102'}
# X0002767499 {'address': '58 RUE DE MOUVAUX', 'state': '18050', 'altcontactcountry': '595120101'}
# X0002765747 {'address': '4 RUE DE LA POTENNERIE', 'state': '9821', 'altcontactcountry': '595120802'}
# X0002695754 {'address': '3 B RUE DU CHEMIN DE FER', 'state': '11113', 'altcontactcountry': '595120602'}
# X0002697185 {'address': '3 RUE DE LA POTENNERIE', 'state': '12305', 'altcontactcountry': '595120802'}
# X0002697086 {'address': '107 B RUE DE DENAIN', 'state': '14603', 'altcontactcountry': '595120801'}
# X0002697697 {'address': '4 RUE MAZAGRAN', 'state': '12853', 'altcontactcountry': '595120302'}
# X0002611709 {'address': '29 RUE DE SAINT AMAND', 'state': '18490', 'altcontactcountry': '595120903'}
# X0002699707 {'address': '169 RUE EDOUARD VAILLANT', 'state': '12501', 'altcontactcountry': '595120703'}
# X0002700076 {'address': '169 RUE EDOUARD VAILLANT', 'state': '12501', 'altcontactcountry': '595120703'}
# X0002710716 {'address': '9 RUE PELLART', 'state': '8334', 'altcontactcountry': '595120402'}
# X0002711195 {'address': '36 RUE COLIGNY', 'state': '20082', 'altcontactcountry': '595120801'}
# X0002697789 {'address': '25 RUE HENRI CARRETTE', 'state': '8369', 'altcontactcountry': '595120201'}
# X0002711263 {'address': '19 RUE HENRI CARRETTE', 'state': '19720', 'altcontactcountry': '595120201'}
# X0002711256 {'address': '19 RUE HENRI CARRETTE', 'state': '19720', 'altcontactcountry': '595120201'}
# X0002712680 {'address': '46 RUE DE BARBIEUX', 'state': '20789', 'altcontactcountry': '595120701'}
# X0002712673 {'address': '46 RUE DE BARBIEUX', 'state': '20789', 'altcontactcountry': '595120701'}
# X0002713557 {'address': '24 AVENUE JEAN JAURES', 'state': '21835', 'altcontactcountry': '595120701'}
# X0002713533 {'address': '30 RUE DE LA PERCHE', 'state': '13620', 'altcontactcountry': '595120503'}
# X0002220215 {'address': '16 RUE DE CROUY', 'state': '8938', 'altcontactcountry': '595120504'}
# X0002769295 {'address': '12 RUE BEAUMARCHAIS', 'state': '12002', 'altcontactcountry': '595121203'}
# X0002768748 {'address': '111 BOULEVARD DE MULHOUSE', 'state': '7024', 'altcontactcountry': '595121001'}
# X0002768724 {'address': '54 RUE DE MONS', 'state': '11844', 'altcontactcountry': '595121001'}
# X0002768670 {'address': '16 RUE DE MONS', 'state': '14309', 'altcontactcountry': '595121001'}
# X0002694030 {'address': '32 RUE DE BEAUMONT', 'state': '595120000010991', 'altcontactcountry': '595120702'}
# X0002692722 {'address': '81 RUE DE VALMY', 'state': '2349', 'altcontactcountry': '595120903'}
# X0002692548 {'address': '2 RUE DE LA POTENNERIE', 'state': '14632', 'altcontactcountry': '595120802'}
# X0002690551 {'address': '57 RUE DE ROCROI', 'state': '522', 'altcontactcountry': '595120901'}
# X0002715391 {'address': '1 RUE LEO LAGRANGE', 'state': '436', 'altcontactcountry': '595121102'}
# X0002715636 {'address': '19 RUE ROUGET DE LISLE', 'state': '11651', 'altcontactcountry': '595120902'}
# X0002716923 {'address': '171 RUE DE LILLE', 'state': '18355', 'altcontactcountry': '595120701'}
# X0002717524 {'address': '34 CONTOUR DES VERTES ALLEES', 'state': '17138', 'altcontactcountry': '595120703'}
# X0002717838 {'address': '60 RUE DU MARECHAL FOCH', 'state': '8927', 'altcontactcountry': '595120601'}
# X0002718668 {'address': '39 PLACE DE LA NATION', 'state': '12988', 'altcontactcountry': '595120402'}
# X0002257266 {'address': '6 PLACE DES TROIS PONTS', 'state': '595120000006720', 'altcontactcountry': '595121102'}
# X0002718729 {'address': '41 RUE DE CASSEL', 'state': '4031', 'altcontactcountry': '595120203'}
# X0002720227 {'address': '75 RUE DESAIX', 'state': '11928', 'altcontactcountry': '595121002'}
# X0002725222 {'address': '57 RUE DU GRAND CHEMIN', 'state': '8645', 'altcontactcountry': '595120504'}
# X0002725147 {'address': '192 RUE DUPUY DE LOME', 'state': '2114', 'altcontactcountry': '595120803'}
# X0001947411 {'address': '8 RUE JULES MICHELET', 'state': '14847', 'altcontactcountry': '595121302'}
# X0002721200 {'address': '85 RUE LA FONTAINE', 'state': '16297', 'altcontactcountry': '595120901'}
# X0002721446 {'address': '7 RUE D ORAN', 'state': '24495', 'altcontactcountry': '595120302'}
# X0002686547 {'address': '22 T AVENUE GUSTAVE DELORY', 'state': '19932', 'altcontactcountry': '595120702'}
# X0002688039 {'address': '54 RUE VAN DYCK', 'state': '19504', 'altcontactcountry': '595121301'}
# X0002688749 {'address': '9 RUE DES TISSERANDS', 'state': '22399', 'altcontactcountry': '595120201'}
# X0002688725 {'address': '10 ALLEE DUPLEIX', 'state': '19453', 'altcontactcountry': '595121302'}
# X0002680071 {'address': '55 RUE DAMMARTIN', 'state': '17051', 'altcontactcountry': '595120701'}
# X0002679297 {'address': '27 RUE HENRI CARRETTE', 'state': '13212', 'altcontactcountry': '595120201'}
# X0002679877 {'address': '4 RUE DES GRAPPERIES', 'state': '13509', 'altcontactcountry': '595120101'}
# x0002840130 {'address': '167 B RUE DE LANNOY', 'state': '22929', 'altcontactcountry': '595120903'}
# X0002839998 {'address': '136 RUE DE L HOMMELET', 'state': '24234', 'altcontactcountry': '595120402'}
# X0002839264 {'address': '14 RUE SAINT ANTOINE', 'state': '13203', 'altcontactcountry': '595120201'}
# X0002613208 {'address': '88 RUE DU FRESNOY', 'state': '6282', 'altcontactcountry': '595120102'}
# X0002838472 {'address': '27 RUE EDOUARD VAILLANT', 'state': '17304', 'altcontactcountry': '595120703'}
# X0002220406 {'address': '17 HAMEAU D EPINAL', 'state': '595120000032069', 'altcontactcountry': '595120102'}
# X0002837857 {'address': '57 RUE DU MARECHAL FOCH', 'state': '8951', 'altcontactcountry': '595120601'}
# X0002837826 {'address': '57 RUE DU MARECHAL FOCH', 'state': '8951', 'altcontactcountry': '595120601'}
# X0002838373 {'address': '19 RUE DE LA COMMUNAUTE URBAINE', 'state': '19851', 'altcontactcountry': '595120602'}
# X0002838342 {'address': '124 RUE DE BEAUREWAERT', 'state': '13929', 'altcontactcountry': '595120903'}
# X0002837178 {'address': '1 QUAI DE BORDEAUX', 'state': '21125', 'altcontactcountry': '595120401'}
# X0002685281 {'address': '141 RUE DE CHARLEROI', 'state': '12158', 'altcontactcountry': '595121102'}
# X0002685229 {'address': '13 RUE DU GENERAL CHANZY', 'state': '17034', 'altcontactcountry': '595120801'}
# X0002685205 {'address': '15 RUE DE BABYLONE', 'state': '16529', 'altcontactcountry': '595121003'}
# X0002685069 {'address': '27 RUE D INKERMANN', 'state': '24106', 'altcontactcountry': '595120504'}
# X0002684505 {'address': '28 RUE HENRI CARRETTE', 'state': '10842', 'altcontactcountry': '595120201'}
# X0002680439 {'address': '27 B BOULEVARD BEAUREPAIRE', 'state': '22052', 'altcontactcountry': '595121003'}
# X0002804484 {'address': '14 B RUE PERROT', 'state': '5770', 'altcontactcountry': '595120403'}
# X0002801094 {'address': '26 RUE DU GENERAL CHANZY', 'state': '9989', 'altcontactcountry': '595120801'}
# X0002801087 {'address': '26 RUE DU GENERAL CHANZY', 'state': '9989', 'altcontactcountry': '595120801'}
# X0002809960 {'address': '35 RUE VALLON', 'state': '13286', 'altcontactcountry': '595120203'}
# X0002808789 {'address': '56 B GRANDE RUE', 'state': '22095', 'altcontactcountry': '595120601'}
# X0002056876 {'address': '45 RUE DE SEBASTOPOL', 'state': '23000', 'altcontactcountry': '595120601'}
# X0002808130 {'address': '18 RUE MOLIERE', 'state': '18788', 'altcontactcountry': '595121001'}
# X0002807898 {'address': '52 RUE DU CUROIR', 'state': '1920', 'altcontactcountry': '595120601'}
# X0002807089 {'address': '28 RUE SAINT JOSEPH', 'state': '15133', 'altcontactcountry': '595120303'}
# X0002080819 {'address': '60 RUE DUGUESCLIN', 'state': '11686', 'altcontactcountry': '595120901'}
# X0002080734 {'address': '60 RUE DUGUESCLIN', 'state': '11686', 'altcontactcountry': '595120901'}
# X0002080833 {'address': '60 RUE DUGUESCLIN', 'state': '11686', 'altcontactcountry': '595120901'}
# X0002842325 {'address': '21 RUE DU VIEIL ABREUVOIR', 'state': '3679', 'altcontactcountry': '595120601'}
# X0002842677 {'address': '140 B RUE DE LANNOY', 'state': '27533', 'altcontactcountry': '595120903'}
# X0002825069 {'address': '93 RUE DE SEBASTOPOL', 'state': '4246', 'altcontactcountry': '595120504'}
# X0002762395 {'address': '187 RUE DU FONTENOY', 'state': '23132', 'altcontactcountry': '595120203'}
# X0002824734 {'address': '22 RUE DE LA BASSE MASURE', 'state': '10747', 'altcontactcountry': '595120303'}
# X0002823430 {'address': '552 RUE DE LANNOY', 'state': '14514', 'altcontactcountry': '595121202'}
# X0002822617 {'address': '160 RUE DU LUXEMBOURG', 'state': '1707', 'altcontactcountry': '595120101'}
# X0002822860 {'address': '160 RUE DU LUXEMBOURG', 'state': '1707', 'altcontactcountry': '595120101'}
# X0002823461 {'address': '160 RUE DU LUXEMBOURG', 'state': '1707', 'altcontactcountry': '595120101'}
# X0002821603 {'address': '0 N RUE DE LA RONDELLE', 'state': '20574', 'altcontactcountry': '595120201'}
# X0002822099 {'address': '15 RUE DE LA POTENNERIE', 'state': '9925', 'altcontactcountry': '595120802'}
# X0002800196 {'address': '61 RUE DU VIEIL ABREUVOIR', 'state': '19835', 'altcontactcountry': '595120602'}
# X0002800202 {'address': '61 RUE DU VIEIL ABREUVOIR', 'state': '19835', 'altcontactcountry': '595120602'}
# X0002799193 {'address': '21 RUE DU DOCTEUR ALBERT SCHWEITZER', 'state': '23144', 'altcontactcountry': '595120603'}
# X0002799216 {'address': '184 RUE DE L INDUSTRIE', 'state': '23674', 'altcontactcountry': '595120502'}
# X0002797045 {'address': '12 RUE HENRI CARRETTE', 'state': '10837', 'altcontactcountry': '595120201'}
# X0002797021 {'address': '12 RUE HENRI CARRETTE', 'state': '10837', 'altcontactcountry': '595120201'}
# X0002797038 {'address': '12 RUE HENRI CARRETTE', 'state': '10837', 'altcontactcountry': '595120201'}
# X0002300962 {'address': '149 RUE DE BEAUREWAERT', 'state': '20739', 'altcontactcountry': '595120903'}
# X0002795829 {'address': '15 RUE VAUBAN', 'state': '18356', 'altcontactcountry': '595120701'}
# X0002789460 {'address': '6 BOULEVARD MONTESQUIEU', 'state': '8835', 'altcontactcountry': '595120503'}
# X0002789453 {'address': '37 RUE EDOUARD VAILLANT', 'state': '17081', 'altcontactcountry': '595120703'}
# X0002789446 {'address': '37 RUE EDOUARD VAILLANT', 'state': '17081', 'altcontactcountry': '595120703'}
# X0002789736 {'address': '37 RUE EDOUARD VAILLANT', 'state': '17081', 'altcontactcountry': '595120703'}
# X0002789668 {'address': '50 RUE DU GENERAL CHANZY', 'state': '2972', 'altcontactcountry': '595120801'}
# X0002788234 {'address': '16 BOULEVARD DE LA REPUBLIQUE', 'state': '10894', 'altcontactcountry': '595120102'}
# X0002789194 {'address': '105 RUE JACQUES PREVERT', 'state': '21256', 'altcontactcountry': '595121003'}
# X0002787114 {'address': '9 ALLEE PIERRE AUGUSTE RENOIR', 'state': '20328', 'altcontactcountry': '595121301'}
# X0002817903 {'address': '9 ALLEE PIERRE AUGUSTE RENOIR', 'state': '20328', 'altcontactcountry': '595121301'}
# X0002787022 {'address': '43 RUE COLIGNY', 'state': '19403', 'altcontactcountry': '595120801'}
# X0002794730 {'address': '90 RUE DROUOT', 'state': '10445', 'altcontactcountry': '595120401'}
# X0002794693 {'address': '18 RUE DE SAINT AMAND', 'state': '13898', 'altcontactcountry': '595120903'}
# X0002794471 {'address': '18 PLACE DES TROIS PONTS', 'state': '595120000006724', 'altcontactcountry': '595121102'}
# X0002794792 {'address': '167 T RUE DE LANNOY', 'state': '22924', 'altcontactcountry': '595120903'}
# X0002843896 {'address': '6 RUE DE LA POTENNERIE', 'state': '2169', 'altcontactcountry': '595120802'}
# X0002794808 {'address': '1 IMPASSE SAINT LOUIS', 'state': '2320', 'altcontactcountry': '595120801'}
# X0002683119 {'address': '118 BOULEVARD D ARMENTIERES', 'state': '23927', 'altcontactcountry': '595120102'}
# X0002791036 {'address': '1 RUE DE LA POTENNERIE', 'state': '595120000018112', 'altcontactcountry': '595120802'}
# X0002790879 {'address': '6 RUE MOLIERE', 'state': '2424', 'altcontactcountry': '595121002'}
# X0002790862 {'address': '6 RUE MOLIERE', 'state': '2424', 'altcontactcountry': '595121002'}
# X0002820361 {'address': '3 PLACE DE LA FOSSE AUX CHENES', 'state': '18406', 'altcontactcountry': '595120201'}
# X0002820316 {'address': '234 RUE DE L EPEULE', 'state': '20838', 'altcontactcountry': '595120502'}
# X0002790381 {'address': '14 RUE HENRI CARRETTE', 'state': '15526', 'altcontactcountry': '595120201'}
# X0002820163 {'address': '34 RUE DE SAINT QUENTIN', 'state': '11595', 'altcontactcountry': '595120903'}
# X0002820156 {'address': '34 RUE DE SAINT QUENTIN', 'state': '11595', 'altcontactcountry': '595120903'}
# X0002817286 {'address': '189 RUE DU COQ FRANCAIS', 'state': '2035', 'altcontactcountry': '595120901'}
# X0002816388 {'address': '42 RUE VALLON', 'state': '10922', 'altcontactcountry': '595120203'}
# X0002815756 {'address': '23 RUE DE BEAUREWAERT', 'state': '514', 'altcontactcountry': '595120903'}
# X0002815367 {'address': '15 RUE DE FAVREUIL', 'state': '11166', 'altcontactcountry': '595120101'}

# %%
rbx.groupby(["state", "address"])['borrowernumber'].count().reset_index().to_csv("med_adresses_20250418.csv", index=False)
